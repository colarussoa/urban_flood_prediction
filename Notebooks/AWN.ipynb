# %%
import requests
import pandas as pd
from pathlib import Path

# 1) paste the JSON endpoint you saw in DevTools (from "Copy as cURL")
#    Examples you might see (pattern varies by station/dashboard view):
#    - https://ambientweather.net/dashboard/<stationID>/tiles?start=...&end=...
#    - https://rt.ambientweather.net/v1/devices/<deviceId>/data?start=...&end=...&limit=...
#    - another /api/... path returning arrays of observations

ENDPOINT = "https://ambientweather.net/dashboard/<stationID>/tiles?start=<unix>&end=<unix>"

ENDPOINT = "https://ambientweather.net/dashboard/<fd3b1c6ad8b91db6d41b3e54873480e4>/tiles?start=<unix>&end=<unix>"

# 2) set a Referer to mimic the dashboard (often not strictly required, but makes it robust)
STATION_DASHBOARD = "https://ambientweather.net/dashboard/<stationID>"

headers = {
    "User-Agent": "Mozilla/5.0",
    "Referer": STATION_DASHBOARD,
}

r = requests.get(ENDPOINT, headers=headers, timeout=30)
r.raise_for_status()
data = r.json()

# If it's a list of observations, normalize directly:
def normalize(obj):
    # Handles both list payloads and dicts with a 'data' field
    if isinstance(obj, list):
        return pd.json_normalize(obj)
    if isinstance(obj, dict):
        # try common keys
        for k in ("data", "observations", "items", "result"):
            if k in obj and isinstance(obj[k], (list, dict)):
                return pd.json_normalize(obj[k])
        return pd.json_normalize(obj)
    return pd.DataFrame()

df = normalize(data)

# Optional: convert epoch seconds to pandas datetime if you see ts fields
for col in df.columns:
    if col.lower() in {"date", "time", "timestamp", "ts"} or col.lower().endswith("time"):
        # try to parse as epoch seconds
        try:
            df[col] = pd.to_datetime(df[col], unit="s", errors="ignore")
        except Exception:
            pass

# Save
out = Path("ambient_export.csv")
# df.to_csv(out, index=False)
# print(f"Saved {len(df):,} rows to {out.resolve()}")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[1], line 22
#      16 headers = {
#      17     "User-Agent": "Mozilla/5.0",
#      18     "Referer": STATION_DASHBOARD,
#      19 }
#      21 r = requests.get(ENDPOINT, headers=headers, timeout=30)
# ---> 22 r.raise_for_status()
#      23 data = r.json()
#      25 # If it's a list of observations, normalize directly:
#
# File ~\Documents\urban_flooding_prediction\Data\weather_sensors\API_pulls\venv\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://ambientweather.net/dashboard/%3CstationID%3E/tiles?start=%3Cunix%3E&end=%3Cunix%3E

# %%
ENDPOINT = "https://ambientweather.net/dashboard/fd3b1c6ad8b91db6d41b3e54873480e4/tiles?start=1724371200&end=1724457600"

# 2) set a Referer to mimic the dashboard (often not strictly required, but makes it robust)
STATION_DASHBOARD = "https://ambientweather.net/dashboard/<stationID>"

headers = {
    "User-Agent": "Mozilla/5.0",
    "Referer": STATION_DASHBOARD,
}

r = requests.get(ENDPOINT, headers=headers, timeout=30)
r.raise_for_status()
data = r.json()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[2], line 12
#       6 headers = {
#       7     "User-Agent": "Mozilla/5.0",
#       8     "Referer": STATION_DASHBOARD,
#       9 }
#      11 r = requests.get(ENDPOINT, headers=headers, timeout=30)
# ---> 12 r.raise_for_status()
#      13 data = r.json()
#
# File ~\Documents\urban_flooding_prediction\Data\weather_sensors\API_pulls\venv\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://ambientweather.net/dashboard/fd3b1c6ad8b91db6d41b3e54873480e4/tiles?start=1724371200&end=1724457600

# %%
import requests, json

ROOT = "https://lightning.ambientweather.net/devices/6686ec9fe2090472957473f5"
headers = {
    "User-Agent": "Mozilla/5.0",
    # Referer usually not required here, but harmless to include:
    "Referer": "https://ambientweather.net/",
}

r = requests.get(ROOT, headers=headers, timeout=30)
print("status:", r.status_code)
print(r.headers.get("content-type"))
print(json.dumps(r.json(), indent=2)[:2000])  # preview first ~2k chars
# Out:
# status: 200
# application/json; charset=utf-8
# {
#   "_id": "6686ec9fe2090472957473f5",
#   "macAddress": "C8:C9:A3:10:32:1D",
#   "lastData": {
#     "stationtype": "AMBWeatherPro_V5.1.1",
#     "dateutc": 1756041360000,
#     "tempf": 86.7,
#     "humidity": 80,
#     "windspeedmph": 0.22,
#     "windgustmph": 1.12,
#     "maxdailygust": 9.17,
#     "winddir": 287,
#     "uv": 3,
#     "solarradiation": 320.04,
#     "hourlyrainin": 0,
#     "eventrainin": 3.571,
#     "dailyrainin": 0,
#     "weeklyrainin": 0,
#     "monthlyrainin": 9.799,
#     "yearlyrainin": 32.26,
#     "totalrainin": 32.26,
#     "baromrelin": 29.772,
#     "baromabsin": 29.982,
#     "type": "weather-data",
#     "created_at": 1756041365720,
#     "feelsLike": 101.98641838029994,
#     "dateutc5": 1756041300000,
#     "lastRain": 1755978300000,
#     "discreets": {
#       "humidity1": [
#         58,
#         57
#       ]
#     },
#     "tz": "America/New_York",
#     "hl": {
#       "dateutc": 1756008000000,
#       "dewPoint": {
#         "h": 79.76877877486689,
#         "l": 76.45147754501252,
#         "c": 134,
#         "s": 10350.8,
#         "ht": 1756041360000,
#         "lt": 1756017840000
#       },
#       "feelsLike": {
#         "h": 101.98641838029994,
#         "l": 89.08946841749993,
#         "c": 134,
#         "s": 12308.72,
#         "ht": 1756041360000,
#         "lt": 1756035840000
#       },
#       "windspeedmph": {
#         "h": 6.04,
#         "l": 0,
#         "c": 67,
#         "s": 61.69,
#         "ht": 1756028640000,
#         "lt": 1756008000000
#       },
#       "windgustmph": {
#         "h": 6.93,
#         "l": 0,
#         "c": 67,
#         "s": 98.29,
#         "ht": 1756014300000,
#         "lt": 1756008000000
#       },
#       "maxdailygust": {
#         "h": 9.17,
#         "l": 3.36,
#         "c": 67,
#         "s": 538.13,
#         "ht": 1756022340000,
#         "lt": 1756008000000
#       },
#       "humidity": {
#         "h": 90,
#         "l": 80,
#         "c": 67,
#         "s": 5594,
#         "ht": 1756037700000,
#         "lt": 1756041300000
#       },
#       "humidityin": {
#         "h": 82,
#         "l": 79,
#         "c": 67,
#         "s": 541

# %%
import time
import math
import requests
import pandas as pd
from datetime import datetime, timezone, timedelta

BASE = "https://lightning.ambientweather.net/device-data"
MAC  = "C8:C9:A3:10:32:1D"  # your macAddress (plain; requests will URL-encode)

HEADERS = {
    "User-Agent": "Mozilla/5.0",
    "Referer": "https://ambientweather.net/",  # usually not required but helps
}

def to_ms(dt):
    # dt as aware UTC datetime → epoch ms
    return int(dt.replace(tzinfo=timezone.utc).timestamp() * 1000)

def fetch_chunk(start_dt, end_dt, data_key="yesterdayData", limit=100, asc=True):
    params = {
        "macAddress": MAC,
        "dataKey": data_key,
        "start": to_ms(start_dt),
        "end": to_ms(end_dt),
        "limit": limit,
        "asc": str(asc).lower(),
    }
    r = requests.get(BASE, params=params, headers=HEADERS, timeout=30)
    r.raise_for_status()
    return r.json()

today_utc = datetime.now(timezone.utc).date()
y_start = datetime.combine(today_utc - timedelta(days=1), datetime.min.time(), tzinfo=timezone.utc)
y_end   = y_start + timedelta(days=1)
payload = fetch_chunk(y_start, y_end, data_key="yesterdayData", limit=100, asc=True)

# %%
import time
import math
import requests
import pandas as pd
from datetime import datetime, timezone, timedelta

BASE = "https://lightning.ambientweather.net/device-data"
MAC  = "C8:C9:A3:10:32:1D"  # your macAddress (plain; requests will URL-encode)

HEADERS = {
    "User-Agent": "Mozilla/5.0",
    "Referer": "https://ambientweather.net/",  # usually not required but helps
}

def to_ms(dt):
    # dt as aware UTC datetime → epoch ms
    return int(dt.replace(tzinfo=timezone.utc).timestamp() * 1000)

def fetch_chunk(start_dt, end_dt, limit=100, asc=True):
    params = {
        "macAddress": MAC,
        "start": to_ms(start_dt),
        "end": to_ms(end_dt),
        "limit": limit,
        "asc": str(asc).lower(),
    }
    r = requests.get(BASE, params=params, headers=HEADERS, timeout=30)
    r.raise_for_status()
    return r.json()

today_utc = datetime.now(timezone.utc).date()
y_start = datetime.combine(today_utc - timedelta(days=7), datetime.min.time(), tzinfo=timezone.utc)
y_end   = y_start + timedelta(days=1)
payload = fetch_chunk(y_start, y_end, limit=1000, asc=True)
len(payload['data'])

# %%
import time
import math
import requests
import pandas as pd
from datetime import datetime, timezone, timedelta

BASE = "https://lightning.ambientweather.net/device-data"
MAC  = "C8:C9:A3:10:32:1D"  # your macAddress (plain; requests will URL-encode)

HEADERS = {
    "User-Agent": "Mozilla/5.0",
    "Referer": "https://ambientweather.net/",  # usually not required but helps
}

def to_ms(dt):
    # dt as aware UTC datetime → epoch ms
    return int(dt.replace(tzinfo=timezone.utc).timestamp() * 1000)

def fetch_chunk(start_dt, end_dt, limit=100, asc=True):
    params = {
        "macAddress": MAC,
        "start": to_ms(start_dt),
        "end": to_ms(end_dt),
        "limit": limit,
        "asc": str(asc).lower(),
    }
    r = requests.get(BASE, params=params, headers=HEADERS, timeout=30)
    r.raise_for_status()
    return r.json()

today_utc = datetime.now(timezone.utc).date()
y_start = datetime.combine(today_utc - timedelta(days=365), datetime.min.time(), tzinfo=timezone.utc)
y_end   = y_start + timedelta(days=1)
payload = fetch_chunk(y_start, y_end, limit=1000, asc=True)
len(payload['data'])
# Out:
# 289

# %%
payload['data']
# Out:
# [{'_id': '66c922aa8564b0825f3d8870',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724457600000,
#   'tempf': 78.1,
#   'humidity': 85,
#   'windspeedmph': 7.83,
#   'windgustmph': 10.29,
#   'maxdailygust': 22.82,
#   'winddir': 138,
#   'uv': 0,
#   'solarradiation': 4.43,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.053,
#   'baromabsin': 30.127,
#   'pm25': 2,
#   'pm25_24h': 3.6,
#   'type': 'weather-data',
#   'created_at': 1724457641821,
#   'ip': '10.138.138.193',
#   'feelsLike': 79.605,
#   'dateutc5': 1724457600000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c923dbb02b312bc3f77b9c',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724457900000,
#   'tempf': 78.3,
#   'humidity': 86,
#   'windspeedmph': 9.17,
#   'windgustmph': 10.29,
#   'maxdailygust': 22.82,
#   'winddir': 161,
#   'uv': 0,
#   'solarradiation': 1.72,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.053,
#   'baromabsin': 30.127,
#   'pm25': 2,
#   'pm25_24h': 3.6,
#   'type': 'weather-data',
#   'created_at': 1724457947019,
#   'ip': '10.138.74.54',
#   'feelsLike': 79.872,
#   'dateutc5': 1724457900000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c9250ce4ffd5d6806fef7e',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724458200000,
#   'tempf': 78.4,
#   'humidity': 86,
#   'windspeedmph': 5.59,
#   'windgustmph': 6.93,
#   'maxdailygust': 22.82,
#   'winddir': 169,
#   'uv': 0,
#   'solarradiation': 0.21,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.062,
#   'baromabsin': 30.135,
#   'pm25': 2,
#   'pm25_24h': 3.6,
#   'type': 'weather-data',
#   'created_at': 1724458251899,
#   'ip': '10.138.234.211',
#   'feelsLike': 79.98200000000001,
#   'dateutc5': 1724458200000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c9263de4ddc6b4fcea51e6',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724458500000,
#   'tempf': 77.9,
#   'humidity': 85,
#   'windspeedmph': 7.83,
#   'windgustmph': 11.41,
#   'maxdailygust': 22.82,
#   'winddir': 103,
#   'uv': 0,
#   'solarradiation': 0.08,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.059,
#   'baromabsin': 30.132,
#   'pm25': 3,
#   'pm25_24h': 3.6,
#   'type': 'weather-data',
#   'created_at': 1724458556963,
#   'ip': '162.158.166.220',
#   'feelsLike': 79.385,
#   'dateutc5': 1724458500000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c927329e68b9dddf2b3545',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724458800000,
#   'tempf': 77.7,
#   'humidity': 84,
#   'windspeedmph': 7.38,
#   'windgustmph': 8.05,
#   'maxdailygust': 22.82,
#   'winddir': 119,
#   'uv': 0,
#   'solarradiation': 0.04,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.064,
#   'baromabsin': 30.138,
#   'pm25': 3,
#   'pm25_24h': 3.6,
#   'type': 'weather-data',
#   'created_at': 1724458800983,
#   'ip': '162.158.167.111',
#   'feelsLike': 79.118,
#   'dateutc5': 1724458800000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c928623eddfd8de3343363',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724459100000,
#   'tempf': 77.9,
#   'humidity': 83,
#   'windspeedmph': 8.28,
#   'windgustmph': 11.41,
#   'maxdailygust': 22.82,
#   'winddir': 158,
#   'uv': 0,
#   'solarradiation': 0.02,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.056,
#   'baromabsin': 30.129,
#   'pm25': 2,
#   'pm25_24h': 3.6,
#   'type': 'weather-data',
#   'created_at': 1724459106116,
#   'ip': '10.138.86.31',
#   'feelsLike': 79.291,
#   'dateutc5': 1724459100000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c929935cbc7eb95887b1dc',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724459400000,
#   'tempf': 77.9,
#   'humidity': 83,
#   'windspeedmph': 4.03,
#   'windgustmph': 5.82,
#   'maxdailygust': 22.82,
#   'winddir': 108,
#   'uv': 0,
#   'solarradiation': 0.01,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.062,
#   'baromabsin': 30.135,
#   'pm25': 2,
#   'pm25_24h': 3.6,
#   'type': 'weather-data',
#   'created_at': 1724459411080,
#   'ip': '10.138.170.129',
#   'feelsLike': 79.291,
#   'dateutc5': 1724459400000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c92ac58f3ac43a7c943578',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724459700000,
#   'tempf': 77.9,
#   'humidity': 83,
#   'windspeedmph': 6.49,
#   'windgustmph': 6.93,
#   'maxdailygust': 22.82,
#   'winddir': 128,
#   'uv': 0,
#   'solarradiation': 0.01,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.053,
#   'baromabsin': 30.127,
#   'pm25': 2,
#   'pm25_24h': 3.6,
#   'type': 'weather-data',
#   'created_at': 1724459716109,
#   'ip': '162.158.167.86',
#   'feelsLike': 79.291,
#   'dateutc5': 1724459700000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c92bf581822d02a773276f',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724460000000,
#   'tempf': 78.3,
#   'humidity': 83,
#   'windspeedmph': 4.47,
#   'windgustmph': 5.82,
#   'maxdailygust': 22.82,
#   'winddir': 96,
#   'uv': 0,
#   'solarradiation': 0.01,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.05,
#   'baromabsin': 30.124,
#   'pm25': 2,
#   'pm25_24h': 3.6,
#   'type': 'weather-data',
#   'created_at': 1724460020719,
#   'ip': '172.71.159.13',
#   'feelsLike': 79.731,
#   'dateutc5': 1724460000000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c92d26421e976f2d5e7262',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724460300000,
#   'tempf': 78.6,
#   'humidity': 83,
#   'windspeedmph': 7.16,
#   'windgustmph': 8.05,
#   'maxdailygust': 22.82,
#   'winddir': 118,
#   'uv': 0,
#   'solarradiation': 0.01,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.05,
#   'baromabsin': 30.124,
#   'pm25': 1,
#   'pm25_24h': 3.6,
#   'type': 'weather-data',
#   'created_at': 1724460325812,
#   'ip': '172.69.135.46',
#   'feelsLike': 80.06099999999999,
#   'dateutc5': 1724460300000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c92e58b520e160f6af4e75',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724460600000,
#   'tempf': 79,
#   'humidity': 82,
#   'windspeedmph': 4.92,
#   'windgustmph': 6.93,
#   'maxdailygust': 22.82,
#   'winddir': 126,
#   'uv': 0,
#   'solarradiation': 0.01,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.047,
#   'baromabsin': 30.121,
#   'pm25': 1,
#   'pm25_24h': 3.6,
#   'type': 'weather-data',
#   'created_at': 1724460630904,
#   'ip': '10.138.33.140',
#   'feelsLike': 80.454,
#   'dateutc5': 1724460600000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c92f88d2f95407fa514133',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724460900000,
#   'tempf': 79.2,
#   'humidity': 82,
#   'windspeedmph': 4.25,
#   'windgustmph': 4.47,
#   'maxdailygust': 22.82,
#   'winddir': 125,
#   'uv': 0,
#   'solarradiation': 0.01,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.047,
#   'baromabsin': 30.121,
#   'pm25': 1,
#   'pm25_24h': 3.6,
#   'type': 'weather-data',
#   'created_at': 1724460935869,
#   'ip': '172.69.23.214',
#   'feelsLike': 80.67399999999999,
#   'dateutc5': 1724460900000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c930b99e68b9dddf2be8fa',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724461200000,
#   'tempf': 79.2,
#   'humidity': 82,
#   'windspeedmph': 5.14,
#   'windgustmph': 5.82,
#   'maxdailygust': 22.82,
#   'winddir': 159,
#   'uv': 0,
#   'solarradiation': 0.01,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.038,
#   'baromabsin': 30.112,
#   'pm25': 1,
#   'pm25_24h': 3.6,
#   'type': 'weather-data',
#   'created_at': 1724461240927,
#   'ip': '10.138.80.59',
#   'feelsLike': 80.67399999999999,
#   'dateutc5': 1724461200000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c931eab8fc6c7ea19d4e31',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724461500000,
#   'tempf': 79.2,
#   'humidity': 82,
#   'windspeedmph': 3.13,
#   'windgustmph': 4.47,
#   'maxdailygust': 22.82,
#   'winddir': 91,
#   'uv': 0,
#   'solarradiation': 0,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.044,
#   'baromabsin': 30.118,
#   'pm25': 2,
#   'pm25_24h': 3.6,
#   'type': 'weather-data',
#   'created_at': 1724461545980,
#   'ip': '162.158.166.132',
#   'feelsLike': 80.67399999999999,
#   'dateutc5': 1724461500000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c9331bcc5f9d11fbb808ee',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724461800000,
#   'tempf': 79,
#   'humidity': 83,
#   'windspeedmph': 5.82,
#   'windgustmph': 6.93,
#   'maxdailygust': 22.82,
#   'winddir': 73,
#   'uv': 0,
#   'solarradiation': 0.01,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.05,
#   'baromabsin': 30.124,
#   'pm25': 2,
#   'pm25_24h': 3.6,
#   'type': 'weather-data',
#   'created_at': 1724461851010,
#   'ip': '10.138.234.211',
#   'feelsLike': 80.50099999999999,
#   'dateutc5': 1724461800000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c9344c6018bc286dea61ac',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724462100000,
#   'tempf': 79,
#   'humidity': 84,
#   'windspeedmph': 3.13,
#   'windgustmph': 3.36,
#   'maxdailygust': 22.82,
#   'winddir': 62,
#   'uv': 0,
#   'solarradiation': 0,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.047,
#   'baromabsin': 30.121,
#   'pm25': 3,
#   'pm25_24h': 3.6,
#   'type': 'weather-data',
#   'created_at': 1724462156045,
#   'ip': '172.69.23.133',
#   'feelsLike': 80.54799999999999,
#   'dateutc5': 1724462100000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c93541f0e74576fe4e688a',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724462400000,
#   'tempf': 79,
#   'humidity': 84,
#   'windspeedmph': 6.49,
#   'windgustmph': 8.05,
#   'maxdailygust': 22.82,
#   'winddir': 109,
#   'uv': 0,
#   'solarradiation': 0.01,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.047,
#   'baromabsin': 30.121,
#   'pm25': 3,
#   'pm25_24h': 3.6,
#   'type': 'weather-data',
#   'created_at': 1724462400120,
#   'ip': '172.71.158.10',
#   'feelsLike': 80.54799999999999,
#   'dateutc5': 1724462400000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c93671e4ddc6b4fceb5999',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724462700000,
#   'tempf': 79,
#   'humidity': 83,
#   'windspeedmph': 6.04,
#   'windgustmph': 8.05,
#   'maxdailygust': 22.82,
#   'winddir': 60,
#   'uv': 0,
#   'solarradiation': 0,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.047,
#   'baromabsin': 30.121,
#   'pm25': 1,
#   'pm25_24h': 3.6,
#   'type': 'weather-data',
#   'created_at': 1724462705163,
#   'ip': '162.158.167.85',
#   'feelsLike': 80.50099999999999,
#   'dateutc5': 1724462700000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c937a2a9ebbe907ed3ba93',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724463000000,
#   'tempf': 79.2,
#   'humidity': 84,
#   'windspeedmph': 4.25,
#   'windgustmph': 5.82,
#   'maxdailygust': 22.82,
#   'winddir': 59,
#   'uv': 0,
#   'solarradiation': 0,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.044,
#   'baromabsin': 30.118,
#   'pm25': 1,
#   'pm25_24h': 3.6,
#   'type': 'weather-data',
#   'created_at': 1724463010208,
#   'ip': '172.71.154.141',
#   'feelsLike': 80.76799999999999,
#   'dateutc5': 1724463000000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c938d45990393c850cd13f',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724463300000,
#   'tempf': 79,
#   'humidity': 85,
#   'windspeedmph': 5.37,
#   'windgustmph': 8.05,
#   'maxdailygust': 22.82,
#   'winddir': 87,
#   'uv': 0,
#   'solarradiation': 0,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.044,
#   'baromabsin': 30.118,
#   'pm25': 5,
#   'pm25_24h': 3.6,
#   'type': 'weather-data',
#   'created_at': 1724463315291,
#   'ip': '162.158.167.85',
#   'feelsLike': 80.595,
#   'dateutc5': 1724463300000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c93a04965d649b2f603ad1',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724463600000,
#   'tempf': 79,
#   'humidity': 84,
#   'windspeedmph': 3.8,
#   'windgustmph': 5.82,
#   'maxdailygust': 22.82,
#   'winddir': 23,
#   'uv': 0,
#   'solarradiation': 0.01,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.047,
#   'baromabsin': 30.121,
#   'pm25': 5,
#   'pm25_24h': 3.6,
#   'type': 'weather-data',
#   'created_at': 1724463619794,
#   'ip': '162.158.166.220',
#   'feelsLike': 80.54799999999999,
#   'dateutc5': 1724463600000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c93b3581822d02a7743735',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724463900000,
#   'tempf': 79,
#   'humidity': 84,
#   'windspeedmph': 5.82,
#   'windgustmph': 8.05,
#   'maxdailygust': 22.82,
#   'winddir': 67,
#   'uv': 0,
#   'solarradiation': 0,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.05,
#   'baromabsin': 30.124,
#   'pm25': 2,
#   'pm25_24h': 3.6,
#   'type': 'weather-data',
#   'created_at': 1724463924867,
#   'ip': '172.71.158.32',
#   'feelsLike': 80.54799999999999,
#   'dateutc5': 1724463900000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c93c676018bc286deadadb',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724464200000,
#   'tempf': 78.8,
#   'humidity': 85,
#   'windspeedmph': 3.8,
#   'windgustmph': 5.82,
#   'maxdailygust': 22.82,
#   'winddir': 70,
#   'uv': 0,
#   'solarradiation': 0,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.053,
#   'baromabsin': 30.127,
#   'pm25': 2,
#   'pm25_24h': 3.6,
#   'type': 'weather-data',
#   'created_at': 1724464229917,
#   'ip': '10.138.152.148',
#   'feelsLike': 80.37500000000001,
#   'dateutc5': 1724464200000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c93d97ae0cc8827d07c59f',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724464500000,
#   'tempf': 78.8,
#   'humidity': 85,
#   'windspeedmph': 3.36,
#   'windgustmph': 4.47,
#   'maxdailygust': 22.82,
#   'winddir': 32,
#   'uv': 0,
#   'solarradiation': 0.01,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.05,
#   'baromabsin': 30.124,
#   'pm25': 3,
#   'pm25_24h': 3.6,
#   'type': 'weather-data',
#   'created_at': 1724464534983,
#   'ip': '162.158.166.140',
#   'feelsLike': 80.37500000000001,
#   'dateutc5': 1724464500000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c93ec83eddfd8de335c3ca',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724464800000,
#   'tempf': 79,
#   'humidity': 85,
#   'windspeedmph': 3.36,
#   'windgustmph': 5.82,
#   'maxdailygust': 22.82,
#   'winddir': 70,
#   'uv': 0,
#   'solarradiation': 0,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.056,
#   'baromabsin': 30.129,
#   'pm25': 3,
#   'pm25_24h': 3.6,
#   'type': 'weather-data',
#   'created_at': 1724464840023,
#   'ip': '172.69.135.14',
#   'feelsLike': 80.595,
#   'dateutc5': 1724464800000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c93ff95990393c850d41c8',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724465100000,
#   'tempf': 79,
#   'humidity': 84,
#   'windspeedmph': 5.14,
#   'windgustmph': 6.93,
#   'maxdailygust': 22.82,
#   'winddir': 63,
#   'uv': 0,
#   'solarradiation': 0,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.059,
#   'baromabsin': 30.132,
#   'pm25': 6,
#   'pm25_24h': 3.6,
#   'type': 'weather-data',
#   'created_at': 1724465145059,
#   'ip': '162.158.166.168',
#   'feelsLike': 80.54799999999999,
#   'dateutc5': 1724465100000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c9412a965d649b2f60bf00',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724465400000,
#   'tempf': 79.2,
#   'humidity': 84,
#   'windspeedmph': 5.37,
#   'windgustmph': 6.93,
#   'maxdailygust': 22.82,
#   'winddir': 113,
#   'uv': 0,
#   'solarradiation': 0.01,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.056,
#   'baromabsin': 30.129,
#   'pm25': 6,
#   'pm25_24h': 3.7,
#   'type': 'weather-data',
#   'created_at': 1724465450104,
#   'ip': '172.71.154.213',
#   'feelsLike': 80.76799999999999,
#   'dateutc5': 1724465400000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c9425c09d0715861bda835',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724465700000,
#   'tempf': 79,
#   'humidity': 84,
#   'windspeedmph': 4.92,
#   'windgustmph': 6.93,
#   'maxdailygust': 22.82,
#   'winddir': 37,
#   'uv': 0,
#   'solarradiation': 0,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.053,
#   'baromabsin': 30.127,
#   'pm25': 2,
#   'pm25_24h': 3.6,
#   'type': 'weather-data',
#   'created_at': 1724465755153,
#   'ip': '10.138.138.193',
#   'feelsLike': 80.54799999999999,
#   'dateutc5': 1724465700000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c943b00a1edb617875dead',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724466060000,
#   'tempf': 78.8,
#   'humidity': 85,
#   'windspeedmph': 5.59,
#   'windgustmph': 6.93,
#   'maxdailygust': 22.82,
#   'winddir': 65,
#   'uv': 0,
#   'solarradiation': 0,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.047,
#   'baromabsin': 30.121,
#   'pm25': 2,
#   'pm25_24h': 3.6,
#   'type': 'weather-data',
#   'created_at': 1724466060218,
#   'ip': '162.158.166.195',
#   'feelsLike': 80.37500000000001,
#   'dateutc5': 1724466000000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c944805cbc7eb9588965a1',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724466300000,
#   'tempf': 78.6,
#   'humidity': 84,
#   'windspeedmph': 7.38,
#   'windgustmph': 9.17,
#   'maxdailygust': 22.82,
#   'winddir': 39,
#   'uv': 0,
#   'solarradiation': 0.01,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.05,
#   'baromabsin': 30.124,
#   'pm25': 6,
#   'pm25_24h': 3.7,
#   'type': 'weather-data',
#   'created_at': 1724466304274,
#   'ip': '10.138.138.193',
#   'feelsLike': 80.10799999999999,
#   'dateutc5': 1724466300000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c945b1cc5f9d11fbb9430f',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724466600000,
#   'tempf': 78.6,
#   'humidity': 84,
#   'windspeedmph': 3.58,
#   'windgustmph': 4.47,
#   'maxdailygust': 22.82,
#   'winddir': 55,
#   'uv': 0,
#   'solarradiation': 0,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.053,
#   'baromabsin': 30.127,
#   'pm25': 6,
#   'pm25_24h': 3.7,
#   'type': 'weather-data',
#   'created_at': 1724466609292,
#   'ip': '172.69.23.81',
#   'feelsLike': 80.10799999999999,
#   'dateutc5': 1724466600000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c946e35cbc7eb958898cc6',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724466900000,
#   'tempf': 78.6,
#   'humidity': 85,
#   'windspeedmph': 2.24,
#   'windgustmph': 2.24,
#   'maxdailygust': 22.82,
#   'winddir': 57,
#   'uv': 0,
#   'solarradiation': 0,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.05,
#   'baromabsin': 30.124,
#   'pm25': 4,
#   'pm25_24h': 3.7,
#   'type': 'weather-data',
#   'created_at': 1724466914335,
#   'ip': '10.138.234.211',
#   'feelsLike': 80.155,
#   'dateutc5': 1724466900000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c94814d2f95407fa52ea86',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724467200000,
#   'tempf': 78.6,
#   'humidity': 85,
#   'windspeedmph': 3.8,
#   'windgustmph': 4.47,
#   'maxdailygust': 22.82,
#   'winddir': 99,
#   'uv': 0,
#   'solarradiation': 0.01,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.047,
#   'baromabsin': 30.121,
#   'pm25': 4,
#   'pm25_24h': 3.7,
#   'type': 'weather-data',
#   'created_at': 1724467219145,
#   'ip': '10.138.46.136',
#   'feelsLike': 80.155,
#   'dateutc5': 1724467200000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c949443eddfd8de336770c',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724467500000,
#   'tempf': 78.6,
#   'humidity': 86,
#   'windspeedmph': 4.03,
#   'windgustmph': 4.47,
#   'maxdailygust': 22.82,
#   'winddir': 89,
#   'uv': 0,
#   'solarradiation': 0,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.044,
#   'baromabsin': 30.118,
#   'pm25': 3,
#   'pm25_24h': 3.7,
#   'type': 'weather-data',
#   'created_at': 1724467524114,
#   'ip': '172.71.158.225',
#   'feelsLike': 80.202,
#   'dateutc5': 1724467500000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c94a75cc5f9d11fbb99b2f',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724467800000,
#   'tempf': 78.6,
#   'humidity': 86,
#   'windspeedmph': 4.92,
#   'windgustmph': 6.93,
#   'maxdailygust': 22.82,
#   'winddir': 100,
#   'uv': 0,
#   'solarradiation': 0,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.047,
#   'baromabsin': 30.121,
#   'pm25': 3,
#   'pm25_24h': 3.7,
#   'type': 'weather-data',
#   'created_at': 1724467829176,
#   'ip': '172.69.23.133',
#   'feelsLike': 80.202,
#   'dateutc5': 1724467800000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c94ba773984bb4b4f14b1c',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724468100000,
#   'tempf': 78.6,
#   'humidity': 86,
#   'windspeedmph': 3.8,
#   'windgustmph': 5.82,
#   'maxdailygust': 22.82,
#   'winddir': 71,
#   'uv': 0,
#   'solarradiation': 0,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.047,
#   'baromabsin': 30.121,
#   'pm25': 6,
#   'pm25_24h': 3.7,
#   'type': 'weather-data',
#   'created_at': 1724468134217,
#   'ip': '172.71.154.136',
#   'feelsLike': 80.202,
#   'dateutc5': 1724468100000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c94cd8bdec126ab0e30ded',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724468400000,
#   'tempf': 78.6,
#   'humidity': 87,
#   'windspeedmph': 3.8,
#   'windgustmph': 5.82,
#   'maxdailygust': 22.82,
#   'winddir': 111,
#   'uv': 0,
#   'solarradiation': 0.01,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.044,
#   'baromabsin': 30.118,
#   'pm25': 6,
#   'pm25_24h': 3.7,
#   'type': 'weather-data',
#   'created_at': 1724468439255,
#   'ip': '172.69.23.81',
#   'feelsLike': 80.249,
#   'dateutc5': 1724468400000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c94e08421e976f2d60a573',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724468700000,
#   'tempf': 78.6,
#   'humidity': 87,
#   'windspeedmph': 6.49,
#   'windgustmph': 8.05,
#   'maxdailygust': 22.82,
#   'winddir': 117,
#   'uv': 0,
#   'solarradiation': 0.01,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.044,
#   'baromabsin': 30.118,
#   'pm25': 5,
#   'pm25_24h': 3.7,
#   'type': 'weather-data',
#   'created_at': 1724468744324,
#   'ip': '172.69.135.157',
#   'feelsLike': 80.249,
#   'dateutc5': 1724468700000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c94f3adbe6f9a375c66611',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724469000000,
#   'tempf': 78.6,
#   'humidity': 87,
#   'windspeedmph': 4.7,
#   'windgustmph': 8.05,
#   'maxdailygust': 22.82,
#   'winddir': 116,
#   'uv': 0,
#   'solarradiation': 0,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.044,
#   'baromabsin': 30.118,
#   'pm25': 5,
#   'pm25_24h': 3.8,
#   'type': 'weather-data',
#   'created_at': 1724469049376,
#   'ip': '10.138.152.148',
#   'feelsLike': 80.249,
#   'dateutc5': 1724469000000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c9506b8f3ac43a7c96c6c3',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724469300000,
#   'tempf': 78.4,
#   'humidity': 87,
#   'windspeedmph': 6.26,
#   'windgustmph': 8.05,
#   'maxdailygust': 22.82,
#   'winddir': 106,
#   'uv': 0,
#   'solarradiation': 0,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.041,
#   'baromabsin': 30.115,
#   'pm25': 4,
#   'pm25_24h': 3.7,
#   'type': 'weather-data',
#   'created_at': 1724469354394,
#   'ip': '10.138.162.225',
#   'feelsLike': 80.02900000000001,
#   'dateutc5': 1724469300000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c951b981822d02a775d0a0',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724469600000,
#   'tempf': 78.4,
#   'humidity': 88,
#   'windspeedmph': 5.59,
#   'windgustmph': 6.93,
#   'maxdailygust': 22.82,
#   'winddir': 90,
#   'uv': 0,
#   'solarradiation': 0,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.047,
#   'baromabsin': 30.121,
#   'pm25': 4,
#   'pm25_24h': 3.7,
#   'type': 'weather-data',
#   'created_at': 1724469659442,
#   'ip': '162.158.166.133',
#   'feelsLike': 80.07600000000001,
#   'dateutc5': 1724469600000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c9528f7890f7ebb6c92758',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724469900000,
#   'tempf': 78.4,
#   'humidity': 89,
#   'windspeedmph': 5.82,
#   'windgustmph': 8.05,
#   'maxdailygust': 22.82,
#   'winddir': 96,
#   'uv': 0,
#   'solarradiation': 0,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.044,
#   'baromabsin': 30.118,
#   'pm25': 5,
#   'pm25_24h': 3.7,
#   'type': 'weather-data',
#   'created_at': 1724469903509,
#   'ip': '172.71.159.14',
#   'feelsLike': 80.12300000000002,
#   'dateutc5': 1724469900000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c953c11bffad7afa4e25fc',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724470200000,
#   'tempf': 78.3,
#   'humidity': 89,
#   'windspeedmph': 6.04,
#   'windgustmph': 8.05,
#   'maxdailygust': 22.82,
#   'winddir': 68,
#   'uv': 0,
#   'solarradiation': 0,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.044,
#   'baromabsin': 30.118,
#   'pm25': 5,
#   'pm25_24h': 3.7,
#   'type': 'weather-data',
#   'created_at': 1724470208561,
#   'ip': '10.138.116.168',
#   'feelsLike': 80.013,
#   'dateutc5': 1724470200000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c954f23eddfd8de337408b',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724470500000,
#   'tempf': 78.3,
#   'humidity': 89,
#   'windspeedmph': 4.7,
#   'windgustmph': 6.93,
#   'maxdailygust': 22.82,
#   'winddir': 107,
#   'uv': 0,
#   'solarradiation': 0,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.035,
#   'baromabsin': 30.109,
#   'pm25': 5,
#   'pm25_24h': 3.7,
#   'type': 'weather-data',
#   'created_at': 1724470513569,
#   'ip': '10.138.58.160',
#   'feelsLike': 80.013,
#   'dateutc5': 1724470500000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c956225cbc7eb9588a8235',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724470800000,
#   'tempf': 78.3,
#   'humidity': 89,
#   'windspeedmph': 4.47,
#   'windgustmph': 4.47,
#   'maxdailygust': 22.82,
#   'winddir': 79,
#   'uv': 0,
#   'solarradiation': 0,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.038,
#   'baromabsin': 30.112,
#   'pm25': 5,
#   'pm25_24h': 3.8,
#   'type': 'weather-data',
#   'created_at': 1724470818208,
#   'ip': '172.69.22.29',
#   'feelsLike': 80.013,
#   'dateutc5': 1724470800000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c957533095bfa9635eb866',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724471100000,
#   'tempf': 78.4,
#   'humidity': 88,
#   'windspeedmph': 4.03,
#   'windgustmph': 5.82,
#   'maxdailygust': 22.82,
#   'winddir': 78,
#   'uv': 0,
#   'solarradiation': 0,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.029,
#   'baromabsin': 30.103,
#   'pm25': 3,
#   'pm25_24h': 3.7,
#   'type': 'weather-data',
#   'created_at': 1724471123258,
#   'ip': '172.69.135.45',
#   'feelsLike': 80.07600000000001,
#   'dateutc5': 1724471100000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c95885ae0cc8827d0970bb',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724471400000,
#   'tempf': 78.6,
#   'humidity': 87,
#   'windspeedmph': 2.46,
#   'windgustmph': 3.36,
#   'maxdailygust': 22.82,
#   'winddir': 104,
#   'uv': 0,
#   'solarradiation': 0,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.032,
#   'baromabsin': 30.106,
#   'pm25': 3,
#   'pm25_24h': 3.7,
#   'type': 'weather-data',
#   'created_at': 1724471428316,
#   'ip': '172.71.158.10',
#   'feelsLike': 80.249,
#   'dateutc5': 1724471400000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c959b6bdec126ab0e3ecf5',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724471700000,
#   'tempf': 78.8,
#   'humidity': 87,
#   'windspeedmph': 2.46,
#   'windgustmph': 3.36,
#   'maxdailygust': 22.82,
#   'winddir': 248,
#   'uv': 0,
#   'solarradiation': 0,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.032,
#   'baromabsin': 30.106,
#   'pm25': 4,
#   'pm25_24h': 3.7,
#   'type': 'weather-data',
#   'created_at': 1724471733384,
#   'ip': '162.158.166.195',
#   'feelsLike': 80.46900000000001,
#   'dateutc5': 1724471700000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c95ae6f0e74576fe51041c',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724472000000,
#   'tempf': 79,
#   'humidity': 85,
#   'windspeedmph': 4.92,
#   'windgustmph': 6.93,
#   'maxdailygust': 6.93,
#   'winddir': 32,
#   'uv': 0,
#   'solarradiation': 0,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.032,
#   'baromabsin': 30.106,
#   'pm25': 4,
#   'pm25_24h': 3.8,
#   'type': 'weather-data',
#   'created_at': 1724472038398,
#   'ip': '10.138.38.147',
#   'feelsLike': 80.595,
#   'dateutc5': 1724472000000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c95c188294c599f96e6bac',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724472300000,
#   'tempf': 79,
#   'humidity': 84,
#   'windspeedmph': 5.37,
#   'windgustmph': 6.93,
#   'maxdailygust': 8.05,
#   'winddir': 125,
#   'uv': 0,
#   'solarradiation': 0,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.035,
#   'baromabsin': 30.109,
#   'pm25': 4,
#   'pm25_24h': 3.8,
#   'type': 'weather-data',
#   'created_at': 1724472343464,
#   'ip': '10.138.234.211',
#   'feelsLike': 80.54799999999999,
#   'dateutc5': 1724472300000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c95d495cbc7eb9588af19c',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724472600000,
#   'tempf': 78.8,
#   'humidity': 83,
#   'windspeedmph': 3.8,
#   'windgustmph': 4.47,
#   'maxdailygust': 8.05,
#   'winddir': 112,
#   'uv': 0,
#   'solarradiation': 0,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.032,
#   'baromabsin': 30.106,
#   'pm25': 4,
#   'pm25_24h': 3.8,
#   'type': 'weather-data',
#   'created_at': 1724472648516,
#   'ip': '10.138.162.225',
#   'feelsLike': 80.281,
#   'dateutc5': 1724472600000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c95e7ae4ddc6b4fcedef04',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724472900000,
#   'tempf': 78.6,
#   'humidity': 83,
#   'windspeedmph': 3.36,
#   'windgustmph': 4.47,
#   'maxdailygust': 8.05,
#   'winddir': 47,
#   'uv': 0,
#   'solarradiation': 0,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.029,
#   'baromabsin': 30.103,
#   'pm25': 3,
#   'pm25_24h': 3.8,
#   'type': 'weather-data',
#   'created_at': 1724472953533,
#   'ip': '10.138.33.140',
#   'feelsLike': 80.06099999999999,
#   'dateutc5': 1724472900000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66c95fac3eddfd8de337f8ac',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724473200000,
#   'tempf': 78.6,
#   'humidity': 84,
#   'windspeedmph': 2.91,
#   'windgustmph': 4.47,
#   'maxdailygust': 8.05,
#   'winddir': 111,
#   'uv': 0,
#   'solarradiation': 0,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 30.029,
#   'baromabsin': 30.103,
#   'pm25': 3,
#   'pm25_24h': 3.7,
#   'type': 'weather-data',
#   'created_at': 1724473258563,
#   'ip': '172.71.155.63',
#   'feelsLike': 80.10799999999999,
#   'dateutc5': 1724473200000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
# ...
#   'baromabsin': 30.053,
#   'pm25': 1,
#   'pm25_24h': 2.9,
#   'type': 'weather-data',
#   'created_at': 1724538957069,
#   'ip': '172.71.154.140',
#   'feelsLike': 96.46758924560011,
#   'dateutc5': 1724538900000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66ca614155b560bbc6ef3ebc',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724539200000,
#   'tempf': 86.2,
#   'humidity': 71,
#   'windspeedmph': 1.34,
#   'windgustmph': 2.24,
#   'maxdailygust': 11.41,
#   'winddir': 319,
#   'uv': 0,
#   'solarradiation': 64.47,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 29.973,
#   'baromabsin': 30.047,
#   'pm25': 1,
#   'pm25_24h': 2.9,
#   'type': 'weather-data',
#   'created_at': 1724539200773,
#   'ip': '172.71.154.19',
#   'feelsLike': 96.0090600807999,
#   'dateutc5': 1724539200000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66ca6271daaa700ae7fa6184',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724539500000,
#   'tempf': 85.8,
#   'humidity': 72,
#   'windspeedmph': 1.79,
#   'windgustmph': 2.24,
#   'maxdailygust': 11.41,
#   'winddir': 289,
#   'uv': 0,
#   'solarradiation': 58.67,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 29.979,
#   'baromabsin': 30.053,
#   'pm25': 3,
#   'pm25_24h': 2.9,
#   'type': 'weather-data',
#   'created_at': 1724539505829,
#   'ip': '172.71.158.33',
#   'feelsLike': 95.44603945759997,
#   'dateutc5': 1724539500000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66ca63a4b02b312bc30dba85',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724539800000,
#   'tempf': 86.5,
#   'humidity': 71,
#   'windspeedmph': 1.12,
#   'windgustmph': 1.12,
#   'maxdailygust': 11.41,
#   'winddir': 297,
#   'uv': 0,
#   'solarradiation': 53.51,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 29.976,
#   'baromabsin': 30.05,
#   'pm25': 3,
#   'pm25_24h': 2.9,
#   'type': 'weather-data',
#   'created_at': 1724539810858,
#   'ip': '172.71.154.4',
#   'feelsLike': 96.77212182999979,
#   'dateutc5': 1724539800000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66ca64d4f0e74576fe63554d',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724540100000,
#   'tempf': 87.4,
#   'humidity': 69,
#   'windspeedmph': 0.67,
#   'windgustmph': 1.12,
#   'maxdailygust': 11.41,
#   'winddir': 286,
#   'uv': 0,
#   'solarradiation': 55.7,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 29.979,
#   'baromabsin': 30.053,
#   'pm25': 4,
#   'pm25_24h': 2.9,
#   'type': 'weather-data',
#   'created_at': 1724540115892,
#   'ip': '10.244.105.6',
#   'feelsLike': 98.10070472240027,
#   'dateutc5': 1724540100000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66ca6605a9ebbe907ee831ec',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724540400000,
#   'tempf': 88.5,
#   'humidity': 66,
#   'windspeedmph': 0.67,
#   'windgustmph': 1.12,
#   'maxdailygust': 11.41,
#   'winddir': 290,
#   'uv': 0,
#   'solarradiation': 52.03,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 29.976,
#   'baromabsin': 30.05,
#   'pm25': 4,
#   'pm25_24h': 2.9,
#   'type': 'weather-data',
#   'created_at': 1724540420974,
#   'ip': '172.69.134.140',
#   'feelsLike': 99.32773814750033,
#   'dateutc5': 1724540400000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66ca673609d0715861d0d7d3',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724540700000,
#   'tempf': 89.4,
#   'humidity': 66,
#   'windspeedmph': 0.22,
#   'windgustmph': 1.12,
#   'maxdailygust': 11.41,
#   'winddir': 298,
#   'uv': 0,
#   'solarradiation': 46.95,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 29.976,
#   'baromabsin': 30.05,
#   'pm25': 2,
#   'pm25_24h': 2.9,
#   'type': 'weather-data',
#   'created_at': 1724540726083,
#   'ip': '172.69.22.43',
#   'feelsLike': 101.66648219120022,
#   'dateutc5': 1724540700000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66ca6867b02b312bc30e14dd',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724541000000,
#   'tempf': 88.9,
#   'humidity': 68,
#   'windspeedmph': 1.57,
#   'windgustmph': 2.24,
#   'maxdailygust': 11.41,
#   'winddir': 275,
#   'uv': 0,
#   'solarradiation': 46.77,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 29.976,
#   'baromabsin': 30.05,
#   'pm25': 2,
#   'pm25_24h': 2.9,
#   'type': 'weather-data',
#   'created_at': 1724541031094,
#   'ip': '10.138.152.148',
#   'feelsLike': 101.51385853030015,
#   'dateutc5': 1724541000000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66ca699809d0715861d1044a',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724541300000,
#   'tempf': 87.3,
#   'humidity': 70,
#   'windspeedmph': 0.22,
#   'windgustmph': 1.12,
#   'maxdailygust': 11.41,
#   'winddir': 286,
#   'uv': 0,
#   'solarradiation': 43.01,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 29.982,
#   'baromabsin': 30.056,
#   'pm25': 2,
#   'pm25_24h': 2.9,
#   'type': 'weather-data',
#   'created_at': 1724541336121,
#   'ip': '172.71.155.64',
#   'feelsLike': 98.3521734003,
#   'dateutc5': 1724541300000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66ca6ac97890f7ebb6dbb69d',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724541600000,
#   'tempf': 87.3,
#   'humidity': 68,
#   'windspeedmph': 1.34,
#   'windgustmph': 2.24,
#   'maxdailygust': 11.41,
#   'winddir': 299,
#   'uv': 0,
#   'solarradiation': 37.03,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 29.979,
#   'baromabsin': 30.053,
#   'pm25': 2,
#   'pm25_24h': 2.9,
#   'type': 'weather-data',
#   'created_at': 1724541641160,
#   'ip': '172.69.135.5',
#   'feelsLike': 97.34556660070004,
#   'dateutc5': 1724541600000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66ca6bfbcc5f9d11fbcd6001',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724541900000,
#   'tempf': 87.1,
#   'humidity': 69,
#   'windspeedmph': 1.12,
#   'windgustmph': 1.12,
#   'maxdailygust': 11.41,
#   'winddir': 312,
#   'uv': 0,
#   'solarradiation': 38.29,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 29.979,
#   'baromabsin': 30.053,
#   'pm25': 2,
#   'pm25_24h': 2.9,
#   'type': 'weather-data',
#   'created_at': 1724541946180,
#   'ip': '10.138.33.140',
#   'feelsLike': 97.33590586039996,
#   'dateutc5': 1724541900000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66ca6d2bf0e74576fe63f2c5',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724542200000,
#   'tempf': 87.1,
#   'humidity': 69,
#   'windspeedmph': 1.12,
#   'windgustmph': 1.12,
#   'maxdailygust': 11.41,
#   'winddir': 305,
#   'uv': 0,
#   'solarradiation': 38.6,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 29.982,
#   'baromabsin': 30.056,
#   'pm25': 2,
#   'pm25_24h': 2.9,
#   'type': 'weather-data',
#   'created_at': 1724542251257,
#   'ip': '162.158.167.121',
#   'feelsLike': 97.33590586039996,
#   'dateutc5': 1724542200000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66ca6e5ccc5f9d11fbcd8c83',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724542500000,
#   'tempf': 87.1,
#   'humidity': 69,
#   'windspeedmph': 3.13,
#   'windgustmph': 4.47,
#   'maxdailygust': 11.41,
#   'winddir': 29,
#   'uv': 0,
#   'solarradiation': 28.66,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 29.982,
#   'baromabsin': 30.056,
#   'pm25': 3,
#   'pm25_24h': 2.9,
#   'type': 'weather-data',
#   'created_at': 1724542556300,
#   'ip': '172.71.154.17',
#   'feelsLike': 97.33590586039996,
#   'dateutc5': 1724542500000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66ca6fb0421e976f2d73ec39',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724542860000,
#   'tempf': 87.3,
#   'humidity': 68,
#   'windspeedmph': 5.37,
#   'windgustmph': 6.93,
#   'maxdailygust': 11.41,
#   'winddir': 318,
#   'uv': 0,
#   'solarradiation': 21.46,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 29.979,
#   'baromabsin': 30.053,
#   'pm25': 3,
#   'pm25_24h': 2.9,
#   'type': 'weather-data',
#   'created_at': 1724542860946,
#   'ip': '162.158.167.49',
#   'feelsLike': 97.34556660070004,
#   'dateutc5': 1724542800000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66ca70810a1edb6178888df0',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724543100000,
#   'tempf': 87.3,
#   'humidity': 68,
#   'windspeedmph': 2.24,
#   'windgustmph': 2.24,
#   'maxdailygust': 11.41,
#   'winddir': 13,
#   'uv': 0,
#   'solarradiation': 18.38,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 29.979,
#   'baromabsin': 30.053,
#   'pm25': 3,
#   'pm25_24h': 2.9,
#   'type': 'weather-data',
#   'created_at': 1724543105087,
#   'ip': '10.138.240.204',
#   'feelsLike': 97.34556660070004,
#   'dateutc5': 1724543100000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66ca71b2daaa700ae7fb708a',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724543400000,
#   'tempf': 87.3,
#   'humidity': 68,
#   'windspeedmph': 3.13,
#   'windgustmph': 4.47,
#   'maxdailygust': 11.41,
#   'winddir': 315,
#   'uv': 0,
#   'solarradiation': 14.85,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 29.967,
#   'baromabsin': 30.041,
#   'pm25': 3,
#   'pm25_24h': 2.9,
#   'type': 'weather-data',
#   'created_at': 1724543409992,
#   'ip': '162.158.167.57',
#   'feelsLike': 97.34556660070004,
#   'dateutc5': 1724543400000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66ca72e309d0715861d1a179',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724543700000,
#   'tempf': 86.9,
#   'humidity': 69,
#   'windspeedmph': 1.34,
#   'windgustmph': 2.24,
#   'maxdailygust': 11.41,
#   'winddir': 271,
#   'uv': 0,
#   'solarradiation': 11.36,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 29.97,
#   'baromabsin': 30.044,
#   'pm25': 5,
#   'pm25_24h': 2.9,
#   'type': 'weather-data',
#   'created_at': 1724543715055,
#   'ip': '10.138.86.31',
#   'feelsLike': 96.83288703639995,
#   'dateutc5': 1724543700000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724457600000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724457600000.json'},
#  {'_id': '66ca7414a9ebbe907ee92691',
#   'PASSKEY': '94087a0fb69bb1ddc81050b863291c31',
#   'stationtype': 'AMBWeatherPro_V5.1.1',
#   'dateutc': 1724544000000,
#   'tempf': 86.9,
#   'humidity': 69,
#   'windspeedmph': 3.13,
#   'windgustmph': 4.47,
#   'maxdailygust': 11.41,
#   'winddir': 344,
#   'uv': 0,
#   'solarradiation': 6.61,
#   'hourlyrainin': 0,
#   'eventrainin': 0,
#   'dailyrainin': 0,
#   'weeklyrainin': 1.39,
#   'monthlyrainin': 1.39,
#   'yearlyrainin': 1.39,
#   'totalrainin': 1.39,
#   'baromrelin': 29.976,
#   'baromabsin': 30.05,
#   'pm25': 5,
#   'pm25_24h': 3,
#   'type': 'weather-data',
#   'created_at': 1724544020136,
#   'ip': '10.138.234.211',
#   'feelsLike': 96.83288703639995,
#   'dateutc5': 1724544000000,
#   'lastRain': 1724353680000,
#   'deviceId': '6686ec9fe2090472957473f5',
#   'passkey': '94087a0fb69bb1ddc81050b863291c31',
#   'time': 1724544000000,
#   'loc': '94087a0fb69bb1ddc81050b863291c31/daily/1724544000000.json'}]

# %%
import time, random
import requests, pandas as pd
from datetime import datetime, timezone, timedelta
from urllib3.util.retry import Retry
from requests.adapters import HTTPAdapter

BASE = "https://lightning.ambientweather.net/device-data"
MAC  = "C8:C9:A3:10:32:1D"

HEADERS = {
    "User-Agent": "Mozilla/5.0",
    "Referer": "https://ambientweather.net/",
    "Accept": "application/json, text/plain, */*",
    "Connection": "keep-alive",     # you can also try "close" if drops persist
}

def to_ms(dt):
    return int(dt.replace(tzinfo=timezone.utc).timestamp() * 1000)

# --- robust session with retries/backoff ---
session = requests.Session()
retry = Retry(
    total=8,
    connect=5,
    read=5,
    status=5,
    backoff_factor=0.5,                 # 0.5,1,2,4,8s...
    status_forcelist=[429, 500, 502, 503, 504],
    allowed_methods=["GET"],
    raise_on_status=False,
)
session.mount("https://", HTTPAdapter(max_retries=retry))

def fetch_chunk(start_dt, end_dt, asc=True):
    params = {
        "macAddress": MAC,
        "start": to_ms(start_dt),
        "end": to_ms(end_dt),
        "asc": str(asc).lower(),
    }
    # small jitter to avoid hammering
    time.sleep(0.2 + random.random() * 0.4)
    r = session.get(BASE, params=params, headers=HEADERS, timeout=(5, 30))
    # If server closed w/out response, requests+Retry will auto-retry. Still check:
    r.raise_for_status()
    return r.json()

def normalize(payload):
    rows = payload.get("data", payload if isinstance(payload, list) else [])
    df = pd.json_normalize(rows)
    # convert ms → datetime for any likely time fields
    for c in df.columns:
        lc = c.lower()
        if lc in {"time","timestamp","date","ts"} or lc.endswith("time"):
            try:
                df[c] = pd.to_datetime(df[c], unit="ms", utc=True)
            except Exception:
                pass
    return df

# ---- pull range in smaller windows (6h) ----
end_dt   = datetime.now(timezone.utc)
start_dt = end_dt - timedelta(days=365)
step     = timedelta(hours=6)           # 3–6h is usually very stable

frames = []
t0 = start_dt
while t0 < end_dt:
    t1 = min(t0 + step, end_dt)
    try:
        payload = fetch_chunk(t0, t1, asc=True)
        df = normalize(payload)
        if not df.empty:
            frames.append(df)
    except requests.exceptions.HTTPError as e:
        # print minimal diagnostics and continue
        print(f"[{t0:%Y-%m-%d %H:%M}] HTTPError {e.response.status_code} – {e.response.text[:150]}")
    except requests.exceptions.RequestException as e:
        # covers RemoteDisconnected/ConnectionError etc.
        print(f"[{t0:%Y-%m-%d %H:%M}] transient error: {e}")
        # brief pause before next window
        time.sleep(2)
    t0 = t1

hist = pd.concat(frames, ignore_index=True) if frames else pd.DataFrame()
ts_col = next((c for c in hist.columns if c.lower() in {"time","timestamp","date","ts"} or c.lower().endswith("time")), None)
if ts_col:
    hist.drop_duplicates(subset=[ts_col], inplace=True)
    hist.sort_values(by=ts_col, inplace=True)

hist.to_csv("ambient_history.csv", index=False)
print("saved", len(hist), "rows")
# Out:
# saved 332 rows

# %%
hist
# Out:
#                             _id                           PASSKEY  \
# 0      66c9e77d73984bb4b4fbb034  94087a0fb69bb1ddc81050b863291c31
# 120    66ca7414a9ebbe907ee92691  94087a0fb69bb1ddc81050b863291c31
# 408    66cbc5bd9e68b9dddf5a2ce2  94087a0fb69bb1ddc81050b863291c31
# 696    66cd17275cbc7eb958c9449a  94087a0fb69bb1ddc81050b863291c31
# 984    66ce6892ce08dbe9aa0d606c  94087a0fb69bb1ddc81050b863291c31
# ...                         ...                               ...
# 47282  68a26d35a7468059102965a6  94087a0fb69bb1ddc81050b863291c31
# 47412  68a3be9638123f7e554a9d5b  94087a0fb69bb1ddc81050b863291c31
# 47547  68a510049a012f132a83cbe6  94087a0fb69bb1ddc81050b863291c31
# 47692  68a66182eb495154ae8f287a  94087a0fb69bb1ddc81050b863291c31
# 47830  68a7b33c19590947335e2b2a  94087a0fb69bb1ddc81050b863291c31
#
#                 stationtype        dateutc  tempf  humidity  windspeedmph  \
# 0      AMBWeatherPro_V5.1.1  1724508000000   81.9        82          4.92
# 120    AMBWeatherPro_V5.1.1  1724544000000   86.9        69          3.13
# 408    AMBWeatherPro_V5.1.1  1724630460000   78.6        96          1.79
# 696    AMBWeatherPro_V5.1.1  1724716800000   75.4        99          7.38
# 984    AMBWeatherPro_V5.1.1  1724803200000   74.1        97          1.34
# ...                     ...            ...    ...       ...           ...
# 47282  AMBWeatherPro_V5.1.1  1755475200000   86.4        78          1.79
# 47412  AMBWeatherPro_V5.1.1  1755561600000   80.1        97          0.00
# 47547  AMBWeatherPro_V5.1.1  1755648000000   87.3        74          0.67
# 47692  AMBWeatherPro_V5.1.1  1755734400000   85.5        74          1.34
# 47830  AMBWeatherPro_V5.1.1  1755820860000   85.8        78          0.45
#
#        windgustmph  maxdailygust  winddir  ...          type     created_at  \
# 0             5.82         11.41      146  ...  weather-data  1724508028697
# 120           4.47         11.41      344  ...  weather-data  1724544020136
# 408           2.24         17.22      206  ...  weather-data  1724630460393
# 696           8.05         28.63       67  ...  weather-data  1724716838288
# 984           2.24         19.46      346  ...  weather-data  1724803217420
# ...            ...           ...      ...  ...           ...            ...
# 47282         2.24         15.88      305  ...  weather-data  1755475253647
# 47412         0.00         20.58      294  ...  weather-data  1755561609909
# 47547         1.12         12.53      342  ...  weather-data  1755648004530
# 47692         2.24         12.53      282  ...  weather-data  1755734402244
# 47830         1.12         12.53      294  ...  weather-data  1755820860135
#
#                    ip   feelsLike       dateutc5       lastRain  \
# 0       172.71.154.17   89.047797  1724508000000  1724353680000
# 120    10.138.234.211   96.832887  1724544000000  1724353680000
# 408    172.71.154.137   80.672000  1724630400000  1724630460000
# 696    10.138.138.193   77.293000  1724716800000  1724716800000
# 984      10.138.80.59   75.769000  1724803200000  1724803200000
# ...               ...         ...            ...            ...
# 47282   172.56.73.189   99.978762  1755475200000  1755314100000
# 47412   172.56.77.246   88.692089  1755561600000  1755559800000
# 47547   172.56.79.136  100.472611  1755648000000  1755634560000
# 47692   172.56.73.254   95.550184  1755734400000  1755634560000
# 47830    172.56.76.94   98.209801  1755820800000  1755634560000
#
#                        deviceId                           passkey  \
# 0      6686ec9fe2090472957473f5  94087a0fb69bb1ddc81050b863291c31
# 120    6686ec9fe2090472957473f5  94087a0fb69bb1ddc81050b863291c31
# 408    6686ec9fe2090472957473f5  94087a0fb69bb1ddc81050b863291c31
# 696    6686ec9fe2090472957473f5  94087a0fb69bb1ddc81050b863291c31
# 984    6686ec9fe2090472957473f5  94087a0fb69bb1ddc81050b863291c31
# ...                         ...                               ...
# 47282  6686ec9fe2090472957473f5  94087a0fb69bb1ddc81050b863291c31
# 47412  6686ec9fe2090472957473f5  94087a0fb69bb1ddc81050b863291c31
# 47547  6686ec9fe2090472957473f5  94087a0fb69bb1ddc81050b863291c31
# 47692  6686ec9fe2090472957473f5  94087a0fb69bb1ddc81050b863291c31
# 47830  6686ec9fe2090472957473f5                               NaN
#
#                            time  \
# 0     2024-08-24 00:00:00+00:00
# 120   2024-08-25 00:00:00+00:00
# 408   2024-08-26 00:00:00+00:00
# 696   2024-08-27 00:00:00+00:00
# 984   2024-08-28 00:00:00+00:00
# ...                         ...
# 47282 2025-08-18 00:00:00+00:00
# 47412 2025-08-19 00:00:00+00:00
# 47547 2025-08-20 00:00:00+00:00
# 47692 2025-08-21 00:00:00+00:00
# 47830                       NaT
#
#                                                      loc
# 0      94087a0fb69bb1ddc81050b863291c31/daily/1724457...
# 120    94087a0fb69bb1ddc81050b863291c31/daily/1724544...
# 408    94087a0fb69bb1ddc81050b863291c31/daily/1724630...
# 696    94087a0fb69bb1ddc81050b863291c31/daily/1724716...
# 984    94087a0fb69bb1ddc81050b863291c31/daily/1724803...
# ...                                                  ...
# 47282  94087a0fb69bb1ddc81050b863291c31/daily/1755475...
# 47412  94087a0fb69bb1ddc81050b863291c31/daily/1755561...
# 47547  94087a0fb69bb1ddc81050b863291c31/daily/1755648...
# 47692  94087a0fb69bb1ddc81050b863291c31/daily/1755734...
# 47830                                                NaN
#
# [332 rows x 33 columns]

# %%
import time, random
import requests, pandas as pd
from datetime import datetime, timezone, timedelta
from urllib3.util.retry import Retry
from requests.adapters import HTTPAdapter

BASE = "https://lightning.ambientweather.net/device-data"
MAC  = "C8:C9:A3:10:32:1D"

HEADERS = {
    "User-Agent": "Mozilla/5.0",
    "Referer": "https://ambientweather.net/",
    "Accept": "application/json, text/plain, */*",
    "Connection": "keep-alive",     # you can also try "close" if drops persist
}

def to_ms(dt):
    return int(dt.replace(tzinfo=timezone.utc).timestamp() * 1000)

# --- robust session with retries/backoff ---
session = requests.Session()
retry = Retry(
    total=8,
    connect=5,
    read=5,
    status=5,
    backoff_factor=0.5,                 # 0.5,1,2,4,8s...
    status_forcelist=[429, 500, 502, 503, 504],
    allowed_methods=["GET"],
    raise_on_status=False,
)
session.mount("https://", HTTPAdapter(max_retries=retry))

def fetch_chunk(start_dt, end_dt, asc=True):
    params = {
        "macAddress": MAC,
        "start": to_ms(start_dt),
        "end": to_ms(end_dt),
        "asc": str(asc).lower(),
    }
    # small jitter to avoid hammering
    time.sleep(0.2 + random.random() * 0.4)
    r = session.get(BASE, params=params, headers=HEADERS, timeout=(5, 30))
    # If server closed w/out response, requests+Retry will auto-retry. Still check:
    r.raise_for_status()
    return r.json()

def normalize(payload):
    rows = payload.get("data", payload if isinstance(payload, list) else [])
    df = pd.json_normalize(rows)
    # convert ms → datetime for any likely time fields
    for c in df.columns:
        lc = c.lower()
        if lc in {"time","timestamp","date","ts"} or lc.endswith("time"):
            try:
                df[c] = pd.to_datetime(df[c], unit="ms", utc=True)
            except Exception:
                pass
    return df

# ---- pull range in smaller windows (6h) ----
end_dt   = datetime.now(timezone.utc)
start_dt = end_dt - timedelta(days=365)
step     = timedelta(hours=6)           # 3–6h is usually very stable

frames = []
t0 = start_dt
while t0 < end_dt:
    t1 = min(t0 + step, end_dt)
    try:
        payload = fetch_chunk(t0, t1, asc=True)
        df = normalize(payload)
        if not df.empty:
            frames.append(df)
    except requests.exceptions.HTTPError as e:
        # print minimal diagnostics and continue
        print(f"[{t0:%Y-%m-%d %H:%M}] HTTPError {e.response.status_code} – {e.response.text[:150]}")
    except requests.exceptions.RequestException as e:
        # covers RemoteDisconnected/ConnectionError etc.
        print(f"[{t0:%Y-%m-%d %H:%M}] transient error: {e}")
        # brief pause before next window
        time.sleep(2)
    t0 = t1

hist = pd.concat(frames, ignore_index=True) if frames else pd.DataFrame()
ts_col = next((c for c in hist.columns if c.lower() in {"time","timestamp","date","ts"} or c.lower().endswith("time")), None)
if ts_col:
    hist.drop_duplicates(subset=[ts_col], inplace=True)
    hist.sort_values(by=ts_col, inplace=True)
